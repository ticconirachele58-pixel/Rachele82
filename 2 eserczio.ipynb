# %%
my_string = "I am studying Python"

# %%
print(my_string.upper())             # MAIUSCOLO
# Out:
# I AM STUDYING PYTHON

# %%
print(my_string.lower())             # minuscolo
# Out:
# i am studying python

# %%
print(my_string.replace("Python", "a lot"))  # sostituzione
# Out:
# I am studying a lot

# %%
print(my_string.split())             # lista parole
# Out:
# ['I', 'am', 'studying', 'Python']

# %%
print(my_string.strip())             # rimuove spazi
# Out:
# I am studying Python

# %%
studenti = ["Alex", "Bob", "Cindy", "Dan", "Emma", "Faith", "Grace", "Henry"]

# %%
corsi = ["Cybersecurity", "Data Analyst", "Backend", "Frontend", "Data Analyst", "Backend"]

# %%
# dati mancanti uno alla volta
corsi.append("Frontend")       # per Grace (indice 6)

# %%
corsi.append("Cybersecurity")  # per Henry (indice 7)

# %%
print(corsi)
# Out:
# ['Cybersecurity', 'Data Analyst', 'Backend', 'Frontend', 'Data Analyst', 'Backend', 'Frontend', 'Cybersecurity']
