# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\ticco\OneDrive\Desktop\Epicode\beginner_datasets\insurance.csv")

print("DIMENSIONI:")
print(df.shape)

print("\nANTEPRIMA:")
print(df.head())

print("\nCOLONNE:")
print(df.columns)
# Out:
# DIMENSIONI:
# (1338, 7)
#
# ANTEPRIMA:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
#
# COLONNE:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
# Le spese mediche (charges) variano molto tra regioni ma senza differenze enormi evidenti.
# I fumatori hanno costi molto più alti rispetto ai non fumatori.
# Le differenze tra uomini e donne sono meno marcate rispetto al fattore smoking.
 # Il BMI ha una media stabile e può influenzare i costi assicurativi.

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\ticco\OneDrive\Desktop\Epicode\beginner_datasets\pokemon.csv")

print("DIMENSIONI:")
print(df.shape)

print("\nANTEPRIMA:")
print(df.head())

print("\nCOLONNE:")
print(df.columns)
# Out:
# DIMENSIONI:
# (800, 13)
#
# ANTEPRIMA:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
#
# COLONNE:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=800, step=1)

# %%
print(df.head())
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
# è UN ID QUINDI UN INDICE LOGICO E PASSIAMO A QUESTO PASSAGGIO:
df = df.set_index("#")

print(df.head())
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison    318  45      49       49       65
# 2                Ivysaur  Grass  Poison    405  60      62       63       80
# 3               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# 3      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
# l’ID 3 NON è unico (ci sono forme diverse dello stesso Pokémon) quindi l’indice NON è perfettamente “univoco” al 100%

# %%
df[df["Legendary"] == True]

df[(df["Legendary"] == True) & (df["Type 1"] == "Grass")]
df[(df["Legendary"] == True) & 
   ((df["Type 1"] == "Ice") | (df["Type 1"] == "Fire"))]

df = df.set_index("Name")

df[(df["Generation"] == 1) & 
   (df["Attack"] > 50) & 
   (df["HP"] < 60)]
# Out:
#               Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Charmander      Fire     NaN    309  39      52       43       60       50
# Charmeleon      Fire     NaN    405  58      64       58       80       65
# Wartortle      Water     NaN    405  59      63       80       65       80
# Rattata       Normal     NaN    253  30      56       35       25       35
# Raticate      Normal     NaN    413  55      81       60       50       70
# Spearow       Normal  Flying    262  40      60       30       31       31
# Ekans         Poison     NaN    288  35      60       44       40       54
# Pikachu     Electric     NaN    320  35      55       40       50       50
# Sandshrew     Ground     NaN    300  50      75       85       20       30
# Nidoran♂      Poison     NaN    273  46      57       40       40       40
# Paras            Bug   Grass    285  35      70       55       45       55
# ...

# %%
# IL PROSSIMO dataset non ha encoding UTF-8 ma latin, Il dataset dei pub e circoli in Italia viene caricato utilizzando encoding Latin1 e separatore “;”
# poiché il file non è in formato UTF-8 e non utilizza la virgola come delimitatore. Questo permette a Pandas di leggere correttamente i dati.

import os

print(os.listdir(r"C:\Users\ticco\OneDrive\Desktop\Epicode\beginner_datasets"))
# Out:
# ['amazon.csv', 'anomaly.csv', 'asia_gdp.csv', 'automobile.csv', 'bank.csv', 'bike.csv', 'blood.csv', 'boston.csv', 'cancer.csv', 'concrete.csv', 'credit.csv', 'diabetes.csv', 'diamond.csv', 'elections.csv', 'electrical_grid.csv', 'employee.csv', 'energy.csv', 'facebook.csv', 'forest.csv', 'france.csv', 'germany.csv', 'glass.csv', 'gold.csv', 'heart.csv', 'heart_disease.csv', 'hepatitis.csv', 'house.csv', 'income.csv', 'insurance.csv', 'ipl.csv', 'iris.csv', 'jewellery.csv', 'juice.csv', 'kiva.csv', 'mice.csv', 'migration.csv', 'nba.csv', 'parkinsons.csv', 'pokemon.csv', 'poker.csv', 'population.csv', 'public_health.csv', 'pycaret_datasets.xlsx', 'questions.csv', 'satellite.csv', 'seeds.csv', 'spx.csv', 'traffic.csv', 'tweets.csv', 'wholesale.csv', 'wikipedia.csv', 'wine.csv']

# %%
# ho mprovato a cercare il file ma sul dataset scaricato non l ho trovato nel dataset beginner

# %%
ma la formula per leggere questo tipo di file si può tradurre in: 

    pd.read_csv(file_path, encoding="latin1", sep=";")

# %%
# per fare l'ultimo esercizio non avendo un dataset ne faccio uno io:

import pandas as pd

data = {
    "name": ["Bar Roma", "Enoteca Milano", "Pub Napoli", "Wine Bar Torino", "Circolo Firenze"],
    "city": ["Roma", "Milano", "Napoli", "Torino", "Firenze"],
    "year": [1990, 2005, 2010, 2018, 2000],
    "category": ["bar", "enoteca", "pub", "wine bar", "circolo"]
}

df = pd.DataFrame(data)

df.info()

df.head(1)

df.tail(1)

df.sample(1)

df["year"].unique()

enoteche = df[df["category"] == "enoteca"]
len(enoteche)

enoteche["name"]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      5 non-null      object
#  1   city      5 non-null      object
#  2   year      5 non-null      int64
#  3   category  5 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 292.0+ bytes
# 1    Enoteca Milano
# Name: name, dtype: object
