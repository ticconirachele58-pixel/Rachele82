# %%
numeri = [10, 5, 8, 20, 20, 3, 15]

if len(numeri) < 3:
    print("La lista è troppo corta")
else:
    numeri_ordinati = sorted(numeri, reverse=True)
    top3 = numeri_ordinati[:3]
    print(top3)
# Out:
# [20, 20, 15]

# %%
numeri = [10, 5, 8, 20, 15, 3]
K = 10

filtrati = [n for n in numeri if n >= K]

if len(filtrati) == 0:
    print("Nessun numero maggiore o uguale a K")
else:
    media = sum(filtrati) / len(filtrati)
    print(media)
# Out:
# 15.0

# %%
numeri = [5, 2, 3, 4]

for n in numeri:
    print("*" * n)
# Out:
# *****
# **
# ***
# ****

# %%
lista_cf = [
    "ABCDEF95G01A123B",
    "GHIJKL91M02A321C",
    "MNOPQR89S03A456D",
    "STUVWX95Z04A654E",
    "XYZABC01D05A789F",
    "DEFGHI95J06A987G"
]

cf_con_95 = []

for cf in lista_cf:
    if "95" in cf:
        cf_con_95.append(cf)
        print("CF:", cf)
        print("Cognome:", cf[0:6])
        print("Nome:", cf[6:12])
        print("---")

print("Lista finale:", cf_con_95)
# Out:
# CF: ABCDEF95G01A123B
# Cognome: ABCDEF
# Nome: 95G01A
# ---
# CF: STUVWX95Z04A654E
# Cognome: STUVWX
# Nome: 95Z04A
# ---
# CF: DEFGHI95J06A987G
# Cognome: DEFGHI
# Nome: 95J06A
# ---
# Lista finale: ['ABCDEF95G01A123B', 'STUVWX95Z04A654E', 'DEFGHI95J06A987G']

# %%
studenti = ["Alex", "Bob", "Cindy", "Dan", "Emma", "Faith", "Grace", "Henry"]
corsi = ["Cybersecurity", "Data Analyst", "Backend", "Frontend", "Data Analyst", "Backend", "Frontend", "Cybersecurity"]
edizioni = [1, 2, 3, 2, 2, 1, 3, 3]

for i in range(len(studenti)):
    if edizioni[i] == 1:
        print(studenti[i])
# Out:
# Alex
# Faith

# %%
prezzi = ["100 €", "200 €", "500 €", "10 €", "50 €", "70 €"]

nuovi_prezzi = []

for p in prezzi:
    nuovi_prezzi.append(p.replace("€", "$"))

print(nuovi_prezzi)
# Out:
# ['100 $', '200 $', '500 $', '10 $', '50 $', '70 $']

# %%
studenti = ["Alex", "Bob", "Cindy", "Dan", "Emma", "Faith", "Grace", "Henry", "Isabelle", "John"]

squadra_pari = []
squadra_dispari = []

for i in range(len(studenti)):
    if i % 2 == 0:
        squadra_pari.append(studenti[i])
    else:
        squadra_dispari.append(studenti[i])

print("Squadra pari:", squadra_pari)
print("Squadra dispari:", squadra_dispari)
# Out:
# Squadra pari: ['Alex', 'Cindy', 'Emma', 'Grace', 'Isabelle']
# Squadra dispari: ['Bob', 'Dan', 'Faith', 'Henry', 'John']

# %%
guadagni = [100, 90, 70, 40, 50, 80, 90, 120, 80, 20, 50, 50]

somma = 0

for i in range(len(guadagni)):
    if i == 0:
        print("Mese 1:", guadagni[i], "€ (nessuna media precedente)")
        somma += guadagni[i]
    else:
        media_prec = somma / i

        if guadagni[i] > media_prec:
            confronto = "maggiore"
        else:
            confronto = "minore"

        print(f"Mese {i+1}: {guadagni[i]} € (media prec: {media_prec:.1f} € - il guadagno attuale è {confronto})")

        somma += guadagni[i]
# Out:
# Mese 1: 100 € (nessuna media precedente)
# Mese 2: 90 € (media prec: 100.0 € - il guadagno attuale è minore)
# Mese 3: 70 € (media prec: 95.0 € - il guadagno attuale è minore)
# Mese 4: 40 € (media prec: 86.7 € - il guadagno attuale è minore)
# Mese 5: 50 € (media prec: 75.0 € - il guadagno attuale è minore)
# Mese 6: 80 € (media prec: 70.0 € - il guadagno attuale è maggiore)
# Mese 7: 90 € (media prec: 71.7 € - il guadagno attuale è maggiore)
# Mese 8: 120 € (media prec: 74.3 € - il guadagno attuale è maggiore)
# Mese 9: 80 € (media prec: 80.0 € - il guadagno attuale è minore)
# Mese 10: 20 € (media prec: 80.0 € - il guadagno attuale è minore)
# Mese 11: 50 € (media prec: 74.0 € - il guadagno attuale è minore)
# Mese 12: 50 € (media prec: 71.8 € - il guadagno attuale è minore)
