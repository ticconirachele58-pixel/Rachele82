# %%
str1="windows"

# %%
str2="excel"

# %%
str3="powerpoint"

# %%
str4="word"

# %%
len(str1)
# Out:
# 7

# %%
anno_nonbisestile=365

# %%
giorni = 365
ore = 24
minuti = 60
secondi = 60

# %%
risultato = giorni * ore * minuti * secondi

# %%
print("I secondi in un anno non bisestile sono:", risultato)
# Out:
# I secondi in un anno non bisestile sono: 31536000
